# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\PUNEET\OneDrive\Desktop\Covid Data.csv")

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
df.shape
# Out:
# (1048575, 21)

# %%
df.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
df["died"]=df["DATE_DIED"].apply(lambda x: 0 if x== '9999-99-99'else 1)
df.drop("DATE_DIED" ,axis=1 ,inplace=True)
df.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'INTUBED', 'PNEUMONIA',
#        'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU', 'died'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  PREGNANT  \
# 0      2             1    1             1       97          1   65         2
# 1      2             1    2             1       97          1   72        97
# 2      2             1    2             2        1          2   55        97
# 3      2             1    1             1       97          2   53         2
# 4      2             1    2             1       97          2   68        97
#
#    DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  \
# 0         2     2  ...        2             1              2               2
# 1         2     2  ...        2             1              2               2
# 2         1     2  ...        2             2              2               2
# 3         2     2  ...        2             2              2               2
# 4         1     2  ...        2             1              2               2
#
# ...

# %%
df.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# ...

# %%
for col in df.columns:
    df[col]=df[col].apply(lambda x :np.nan if (x==97 or x==92) else x)

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA   AGE  PREGNANT  \
# 0      2             1    1             1      NaN          1  65.0       2.0
# 1      2             1    2             1      NaN          1  72.0       NaN
# 2      2             1    2             2      1.0          2  55.0       NaN
# 3      2             1    1             1      NaN          2  53.0       2.0
# 4      2             1    2             1      NaN          2  68.0       NaN
#
#    DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  \
# 0         2     2  ...        2             1              2               2
# 1         2     2  ...        2             1              2               2
# 2         1     2  ...        2             2              2               2
# 3         2     2  ...        2             2              2               2
# 4         1     2  ...        2             1              2               2
#
# ...

# %%
df.isnull().sum()
# Out:
# USMER                        0
# MEDICAL_UNIT                 0
# SEX                          0
# PATIENT_TYPE                 0
# INTUBED                 848544
# PNEUMONIA                    0
# AGE                        584
# PREGNANT                523511
# DIABETES                     0
# COPD                         0
# ASTHMA                       0
# INMSUPR                      0
# HIPERTENSION                 0
# OTHER_DISEASE                0
# CARDIOVASCULAR               0
# OBESITY                      0
# RENAL_CHRONIC                0
# TOBACCO                      0
# CLASIFFICATION_FINAL         0
# ICU                     848544
# died                         0
# dtype: int64

# %%
df.drop(["INTUBED","PREGNANT","ICU"],axis=1,inplace =True )

# %%
df.isnull().sum()
# Out:
# USMER                     0
# MEDICAL_UNIT              0
# SEX                       0
# PATIENT_TYPE              0
# PNEUMONIA                 0
# AGE                     584
# DIABETES                  0
# COPD                      0
# ASTHMA                    0
# INMSUPR                   0
# HIPERTENSION              0
# OTHER_DISEASE             0
# CARDIOVASCULAR            0
# OBESITY                   0
# RENAL_CHRONIC             0
# TOBACCO                   0
# CLASIFFICATION_FINAL      0
# died                      0
# dtype: int64

# %%
df.shape
# Out:
# (1048575, 18)

# %%
df["AGE"].mean()
# Out:
# np.float64(41.76548081042681)

# %%
df["AGE"].fillna(df["AGE"].mean() , inplace=True)
# Out:
# C:\Users\PUNEET\AppData\Local\Temp\ipykernel_26192\1070797170.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["AGE"].fillna(df["AGE"].mean() , inplace=True)

# %%
df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# PNEUMONIA               0
# AGE                     0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# died                    0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df , x='PATIENT_TYPE')
plt.title("patient type distribution")
plt.xlabel("1 for outpatient , 2 for hospitalized")
plt.ylabel("count")
plt.show()

# %%
chronic = ['DIABETES', 'COPD', 'ASTHMA', 'INMSUPR', 'HIPERTENSION',
           'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY', 'RENAL_CHRONIC']

plt.figure(figsize=(12,6))
sns.countplot(data=df.melt(value_vars=chronic), x='variable', hue='value' , palette=["blue", "green","black"])
plt.title('Chronic Diseases Distribution')
plt.xlabel('Disease')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
plt.savefig("img.png")

# %%
categ_cols = [
    'USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'PNEUMONIA', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
    'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
    'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL'
]

for col in categ_cols:
    plt.Figure(figsize=(10,6))
    sns.countplot(data=df, x= col , hue="died" ,)
    plt.title(f'{col} distribution of deaths')
    plt.ylabel("count")
    plt.xlabel(col)
    plt.legend(title="dead or alive")
    plt .show()

# %%
sns.displot(df['AGE'])
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(855623)

# %%
df.drop_duplicates(inplace =True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (192952, 18)

# %%
x=df.iloc[ : , 0:17]
y=df.iloc[ : ,-1]

# %%
df.dtypes
# Out:
# USMER                     int64
# MEDICAL_UNIT              int64
# SEX                       int64
# PATIENT_TYPE              int64
# PNEUMONIA                 int64
# AGE                     float64
# DIABETES                  int64
# COPD                      int64
# ASTHMA                    int64
# INMSUPR                   int64
# HIPERTENSION              int64
# OTHER_DISEASE             int64
# CARDIOVASCULAR            int64
# OBESITY                   int64
# RENAL_CHRONIC             int64
# TOBACCO                   int64
# CLASIFFICATION_FINAL      int64
# died                      int64
# dtype: object

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  PNEUMONIA   AGE  DIABETES  COPD  \
# 0      2             1    1             1          1  65.0         2     2
# 1      2             1    2             1          1  72.0         2     2
# 2      2             1    2             2          2  55.0         1     2
# 3      2             1    1             1          2  53.0         2     2
# 4      2             1    2             1          2  68.0         1     2
#
#    ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  \
# 0       2        2             1              2               2        2
# 1       2        2             1              2               2        1
# 2       2        2             2              2               2        2
# 3       2        2             2              2               2        2
# 4       2        2             1              2               2        2
#
#    RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  died
# ...

# %%
plt.hist(df[df['died'] == 0]['AGE'], bins=30, alpha=0.5, label='Alive')
plt.hist(df[df['died'] == 1]['AGE'], bins=30, alpha=0.5, label='Died')

plt.xlabel("AGE")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE()
x_res, y_res = sm.fit_resample(x, y)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(x_res.shape)
print(y_res.shape)
# Out:
# (154361, 17)
# (154361,)
# (38591, 17)
# (38591,)
# (300340, 17)
# (300340,)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(class_weight="balanced")
model.fit(x_res,y_res)
print("trained")
# Out:
# trained

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.91155969008318
# [[27068  3019]
#  [  394  8110]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94     30087
#            1       0.73      0.95      0.83      8504
#
#     accuracy                           0.91     38591
#    macro avg       0.86      0.93      0.88     38591
# weighted avg       0.93      0.91      0.92     38591

# %%
df["died"].value_counts()
# Out:
# died
# 0    150170
# 1     42782
# Name: count, dtype: int64
